# %%
# import packages
import pandas as pd
import csv
import json
## NOTE: I saw how to use the spicy package to get the percentile of a pandas column
## in the first answer of this StackOverflow post.
## Link: https://stackoverflow.com/questions/44824927/calculate-percentile-of-value-in-column
from scipy import stats

# %%
# auxiliar list for adding data
data = []

# read csv file of population
## NOTE: I saw this post of GeeksforGeeks to see how to convert csv to json
## Link: https://www.geeksforgeeks.org/convert-csv-to-json-using-python/
with open("../data/CAINC1_population_levels.csv", newline = "", encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile)
    data_aux = [row for row in reader]
    # generate nested dictionary for population
    for row in data_aux:
        row_dict = {}
        population = {}
        for key in row.keys():
            if key == "GeoFips":
                row_dict[key] = row[key]
            elif key == "GeoName":
                row_dict[key] = row[key]
            else:
                population[key] = row[key]
        row_dict["Population"] = population
        # add population to data
        data.append(row_dict)

# %%
# auxiliar dictionary to store population data change last 5 years
data_aux = {}

# read CSV file in pandas for percentile analysis
df = pd.read_csv("../data/CAINC1_population_percent_5_years.csv")

# read CSV file
with open("../data/CAINC1_population_percent_5_years.csv", newline = "", encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile)
    # generate nested dictionary for income
    for row in reader:
        key = row["GeoFips"]
        row_aux = row.copy()
        del row_aux["GeoFips"]
        del row_aux["GeoName"]
        # There is a typo in the map when value is exactly zero, so I set it as zero + epsilon
        if row_aux["Value"] == "0":
            row_aux["Value"] = "0.00001"
        data_aux[key] = {"PopulationChange5Years" : row_aux}
        # add percentile data
        try:
            percentile = stats.percentileofscore(df["Value"], float(row_aux["Value"]), kind = "strict")
        except Exception:
            percentile = "No data"
        data_aux[key]["PopulationChange5YearsPercentile"] = {"Value" : percentile}

# include per capita income change to dataset
for row in data:
    row["PopulationChange5Years"] = data_aux[row["GeoFips"]]["PopulationChange5Years"]
    row["PopulationChange5YearsPercentile"] = data_aux[row["GeoFips"]]["PopulationChange5YearsPercentile"]

# %%
# auxiliar dictionary to store population data change last 10 years
data_aux = {}

# read CSV file in pandas for percentile analysis
df = pd.read_csv("../data/CAINC1_population_percent_10_years.csv")

# read CSV file
with open("../data/CAINC1_population_percent_10_years.csv", newline = "", encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile)
    # generate nested dictionary for income
    for row in reader:
        key = row["GeoFips"]
        row_aux = row.copy()
        del row_aux["GeoFips"]
        del row_aux["GeoName"]
        # There is a typo in the map when value is exactly zero, so I set it as zero + epsilon
        if row_aux["Value"] == "0":
            row_aux["Value"] = "0.00001"
        data_aux[key] = {"PopulationChange10Years" : row_aux}
        # add percentile data
        try:
            percentile = stats.percentileofscore(df["Value"], float(row_aux["Value"]), kind = "strict")
        except Exception:
            percentile = "No data"
        data_aux[key]["PopulationChange10YearsPercentile"] = {"Value" : percentile}

# include per capita income change to dataset
for row in data:
    row["PopulationChange10Years"] = data_aux[row["GeoFips"]]["PopulationChange10Years"]
    row["PopulationChange10YearsPercentile"] = data_aux[row["GeoFips"]]["PopulationChange10YearsPercentile"]

# %%
# auxiliar dictionary to store general price index
data_aux = {}

# read CSV file in pandas for percentile analysis
df = pd.read_csv("../data/RPP_general_2022.csv")

# read CSV file
with open("../data/RPP_general_2022.csv", newline = "", encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile)
    # generate nested dictionary for income
    for row in reader:
        key = row["GeoFips"]
        row_aux = row.copy()
        del row_aux["GeoFips"]
        del row_aux["GeoName"]
        data_aux[key] = {"GeneralPriceIndex" : row_aux}
        # add percentile data
        try:
            percentile = stats.percentileofscore(df["Value"], float(row_aux["Value"]), kind = "strict")
        except Exception:
            percentile = "No data"
        data_aux[key]["GeneralPriceIndexPercentile"] = {"Value" : percentile}

# include per capita income to dataset
for row in data:
    row["GeneralPriceIndex"] = data_aux[row["GeoFips"]]["GeneralPriceIndex"]
    row["GeneralPriceIndexPercentile"] = data_aux[row["GeoFips"]]["GeneralPriceIndexPercentile"]

# %%
# auxiliar dictionary to store housing price index
data_aux = {}

# read CSV file in pandas for percentile analysis
df = pd.read_csv("../data/RPP_housing_2022.csv")

# read CSV file
with open("../data/RPP_housing_2022.csv", newline = "", encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile)
    # generate nested dictionary for income
    for row in reader:
        key = row["GeoFips"]
        row_aux = row.copy()
        del row_aux["GeoFips"]
        del row_aux["GeoName"]
        data_aux[key] = {"HousingPriceIndex" : row_aux}
        # add percentile data
        try:
            percentile = stats.percentileofscore(df["Value"], float(row_aux["Value"]), kind = "strict")
        except Exception:
            percentile = "No data"
        data_aux[key]["HousingPriceIndexPercentile"] = {"Value" : percentile}

# include per capita income to dataset
for row in data:
    row["HousingPriceIndex"] = data_aux[row["GeoFips"]]["HousingPriceIndex"]
    row["HousingPriceIndexPercentile"] = data_aux[row["GeoFips"]]["HousingPriceIndexPercentile"]

# %%
# auxiliar dictionary to store per capita income data
data_aux = {}

# read CSV file in pandas for percentile analysis
df = pd.read_csv("../data/CAINC1_percapitapersonalincome_levels.csv")

# read CSV file
with open("../data/CAINC1_percapitapersonalincome_levels.csv", newline = "", encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile)
    # generate nested dictionary for income
    for row in reader:
        key = row["GeoFips"]
        row_aux = row.copy()
        del row_aux["GeoFips"]
        del row_aux["GeoName"]
        data_aux[key] = {"PerCapitaIncome" : row_aux}
        # add percentile data
        try:
            percentile = stats.percentileofscore(df["2023"], float(row_aux["2023"]), kind = "strict")
        except Exception:
            percentile = "No data"
        data_aux[key]["PerCapitaIncomePercentile"] = {"Value" : percentile}

# include per capita income to dataset
for row in data:
    row["PerCapitaIncome"] = data_aux[row["GeoFips"]]["PerCapitaIncome"]
    row["PerCapitaIncomePercentile"] = data_aux[row["GeoFips"]]["PerCapitaIncomePercentile"]

# %%
# auxiliar dictionary to store per capita income data change
data_aux = {}

# read CSV file in pandas for percentile analysis
df = pd.read_csv("../data/CAINC1_percapitapersonalincome_percent.csv")

# read CSV file
with open("../data/CAINC1_percapitapersonalincome_percent.csv", newline = "", encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile)
    # generate nested dictionary for income
    for row in reader:
        key = row["GeoFips"]
        row_aux = row.copy()
        del row_aux["GeoFips"]
        del row_aux["GeoName"]
        data_aux[key] = {"PerCapitaIncomeChange" : row_aux}
        # add percentile data
        try:
            percentile = stats.percentileofscore(df["2023"], float(row_aux["2023"]), kind = "strict")
        except Exception:
            percentile = "No data"
        data_aux[key]["PerCapitaIncomeChangePercentile"] = {"Value" : percentile}

# include per capita income change to dataset
for row in data:
    row["PerCapitaIncomeChange"] = data_aux[row["GeoFips"]]["PerCapitaIncomeChange"]
    row["PerCapitaIncomeChangePercentile"] = data_aux[row["GeoFips"]]["PerCapitaIncomeChangePercentile"]

# %%
# auxiliar dictionary to store per capita income data change last 5 years
data_aux = {}

# read CSV file in pandas for percentile analysis
df = pd.read_csv("../data/CAINC1_percapitapersonalincome_percent_5_years.csv")

# read CSV file
with open("../data/CAINC1_percapitapersonalincome_percent_5_years.csv", newline = "", encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile)
    # generate nested dictionary for income
    for row in reader:
        key = row["GeoFips"]
        row_aux = row.copy()
        del row_aux["GeoFips"]
        del row_aux["GeoName"]
        data_aux[key] = {"PerCapitaIncomeChange5Years" : row_aux}
        # add percentile data
        try:
            percentile = stats.percentileofscore(df["Value"], float(row_aux["Value"]), kind = "strict")
        except Exception:
            percentile = "No data"
        data_aux[key]["PerCapitaIncomeChange5YearsPercentile"] = {"Value" : percentile}

# include per capita income change last 5 years to dataset
for row in data:
    row["PerCapitaIncomeChange5Years"] = data_aux[row["GeoFips"]]["PerCapitaIncomeChange5Years"]
    row["PerCapitaIncomeChange5YearsPercentile"] = data_aux[row["GeoFips"]]["PerCapitaIncomeChange5YearsPercentile"]

# %%
# auxiliar dictionary to store per capita income data change last 10 years
data_aux = {}

# read CSV file in pandas for percentile analysis
df = pd.read_csv("../data/CAINC1_percapitapersonalincome_percent_10_years.csv")

# read CSV file
with open("../data/CAINC1_percapitapersonalincome_percent_10_years.csv", newline = "", encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile)
    # generate nested dictionary for income
    for row in reader:
        key = row["GeoFips"]
        row_aux = row.copy()
        del row_aux["GeoFips"]
        del row_aux["GeoName"]
        data_aux[key] = {"PerCapitaIncomeChange10Years" : row_aux}
        # add percentile data
        try:
            percentile = stats.percentileofscore(df["Value"], float(row_aux["Value"]), kind = "strict")
        except Exception:
            percentile = "No data"
        data_aux[key]["PerCapitaIncomeChange10YearsPercentile"] = {"Value" : percentile}

# include per capita income change last 10 years to dataset
for row in data:
    row["PerCapitaIncomeChange10Years"] = data_aux[row["GeoFips"]]["PerCapitaIncomeChange10Years"]
    row["PerCapitaIncomeChange10YearsPercentile"] = data_aux[row["GeoFips"]]["PerCapitaIncomeChange10YearsPercentile"]

# %%
# auxiliar dictionary to store per capita income data change last 20 years
data_aux = {}

# read CSV file in pandas for percentile analysis
df = pd.read_csv("../data/CAINC1_percapitapersonalincome_percent_20_years.csv")

# read CSV file
with open("../data/CAINC1_percapitapersonalincome_percent_20_years.csv", newline = "", encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile)
    # generate nested dictionary for income
    for row in reader:
        key = row["GeoFips"]
        row_aux = row.copy()
        del row_aux["GeoFips"]
        del row_aux["GeoName"]
        data_aux[key] = {"PerCapitaIncomeChange20Years" : row_aux}
        # add percentile data
        try:
            percentile = stats.percentileofscore(df["Value"], float(row_aux["Value"]), kind = "strict")
        except Exception:
            percentile = "No data"
        data_aux[key]["PerCapitaIncomeChange20YearsPercentile"] = {"Value" : percentile}

# include per capita income change last 20 years to dataset
for row in data:
    row["PerCapitaIncomeChange20Years"] = data_aux[row["GeoFips"]]["PerCapitaIncomeChange20Years"]
    row["PerCapitaIncomeChange20YearsPercentile"] = data_aux[row["GeoFips"]]["PerCapitaIncomeChange20YearsPercentile"]

# %%
# auxiliar dictionary to store per capita income data change last 30 years
data_aux = {}

# read CSV file in pandas for percentile analysis
df = pd.read_csv("../data/CAINC1_percapitapersonalincome_percent_30_years.csv")

# read CSV file
with open("../data/CAINC1_percapitapersonalincome_percent_30_years.csv", newline = "", encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile)
    # generate nested dictionary for income
    for row in reader:
        key = row["GeoFips"]
        row_aux = row.copy()
        del row_aux["GeoFips"]
        del row_aux["GeoName"]
        data_aux[key] = {"PerCapitaIncomeChange30Years" : row_aux}
        # add percentile data
        try:
            percentile = stats.percentileofscore(df["Value"], float(row_aux["Value"]), kind = "strict")
        except Exception:
            percentile = "No data"
        data_aux[key]["PerCapitaIncomeChange30YearsPercentile"] = {"Value" : percentile}

# include per capita income change last 30 years to dataset
for row in data:
    row["PerCapitaIncomeChange30Years"] = data_aux[row["GeoFips"]]["PerCapitaIncomeChange30Years"]
    row["PerCapitaIncomeChange30YearsPercentile"] = data_aux[row["GeoFips"]]["PerCapitaIncomeChange30YearsPercentile"]

# %%
# convert data to json
with open("../data/visualization_dataset.json", "w", encoding="utf-8") as jsonfile:
    jsonfile.write(json.dumps(data, indent=4))

# %%
with open("../data/visualization_dataset.json", "r") as file:
    trial = json.load(file)

trial
# Out:
# [{'GeoFips': '00998',
#   'GeoName': 'United States (Metropolitan Portion)',
#   'Population': {'1969': '165312410',
#    '1970': '167673802',
#    '1971': '170105159',
#    '1972': '172046247',
#    '1973': '173780093',
#    '1974': '175466407',
#    '1975': '177030533',
#    '1976': '178686628',
#    '1977': '180432448',
#    '1978': '182401281',
#    '1979': '184484865',
#    '1980': '186782151',
#    '1981': '188778153',
#    '1982': '190745925',
#    '1983': '192718299',
#    '1984': '194703380',
#    '1985': '196876182',
#    '1986': '199228098',
#    '1987': '201492835',
#    '1988': '203720597',
#    '1989': '206023143',
#    '1990': '208731806',
#    '1991': '211749567',
#    '1992': '214894354',
#    '1993': '217865356',
#    '1994': '220657445',
#    '1995': '223370500',
#    '1996': '226131436',
#    '1997': '229081203',
#    '1998': '232040831',
#    '1999': '235008165',
#    '2000': '237948237',
#    '2001': '240717866',
#    '2002': '243260703',
#    '2003': '245592588',
#    '2004': '248115013',
#    '2005': '250646689',
#    '2006': '253256238',
#    '2007': '255922913',
#    '2008': '258627316',
#    '2009': '261210075',
#    '2010': '263718787',
#    '2011': '266205658',
#    '2012': '268779366',
#    '2013': '271230523',
#    '2014': '273817755',
#    '2015': '276425937',
#    '2016': '278995907',
#    '2017': '281262885',
#    '2018': '283180665',
#    '2019': '284873351',
#    '2020': '286193652',
#    '2021': '286656077',
#    '2022': '287835880',
#    '2023': '289370890'},
#   'PopulationChange5Years': {'Value': '0.4'},
#   'PopulationChange5YearsPercentile': {'Value': 51.42857142857142},
#   'PopulationChange10Years': {'Value': '0.6'},
#   'PopulationChange10YearsPercentile': {'Value': 57.14285714285714},
#   'GeneralPriceIndex': {'Value': '100'},
#   'GeneralPriceIndexPercentile': {'Value': 79.48051948051948},
#   'HousingPriceIndex': {'Value': '100.595'},
#   'HousingPriceIndexPercentile': {'Value': 77.4025974025974},
#   'PerCapitaIncome': {'1969': '4138',
#    '1970': '4409',
#    '1971': '4692',
#    '1972': '5086',
#    '1973': '5570',
#    '1974': '6077',
#    '1975': '6585',
#    '1976': '7169',
#    '1977': '7845',
#    '1978': '8715',
#    '1979': '9629',
#    '1980': '10659',
#    '1981': '11796',
#    '1982': '12536',
#    '1983': '13304',
#    '1984': '14527',
#    '1985': '15445',
#    '1986': '16228',
#    '1987': '17015',
#    '1988': '18314',
#    '1989': '19552',
#    '1990': '20551',
#    '1991': '20968',
#    '1992': '22007',
#    '1993': '22660',
#    '1994': '23503',
#    '1995': '24619',
#    '1996': '25794',
#    '1997': '27062',
#    '1998': '28747',
#    '1999': '29931',
#    '2000': '32033',
#    '2001': '32989',
#    '2002': '33213',
#    '2003': '34046',
#    '2004': '35606',
#    '2005': '37180',
#    '2006': '39524',
#    '2007': '41303',
#    '2008': '42479',
#    '2009': '40751',
#    '2010': '41994',
#    '2011': '44112',
#    '2012': '45779',
#    '2013': '45845',
#    '2014': '47836',
#    '2015': '49741',
#    '2016': '50756',
#    '2017': '52884',
#    '2018': '55293',
#    '2019': '57621',
#    '2020': '61179',
#    '2021': '66663',
#    '2022': '68517',
#    '2023': '72275'},
#   'PerCapitaIncomePercentile': {'Value': 85.45454545454545},
#   'PerCapitaIncomeChange': {'1970': '6.5',
#    '1971': '6.4',
#    '1972': '8.4',
#    '1973': '9.5',
#    '1974': '9.1',
#    '1975': '8.4',
#    '1976': '8.9',
#    '1977': '9.4',
#    '1978': '11.1',
#    '1979': '10.5',
#    '1980': '10.7',
#    '1981': '10.7',
#    '1982': '6.3',
#    '1983': '6.1',
#    '1984': '9.2',
#    '1985': '6.3',
#    '1986': '5.1',
#    '1987': '4.8',
#    '1988': '7.6',
#    '1989': '6.8',
#    '1990': '5.1',
#    '1991': '2',
#    '1992': '5',
#    '1993': '3',
#    '1994': '3.7',
#    '1995': '4.7',
#    '1996': '4.8',
#    '1997': '4.9',
#    '1998': '6.2',
#    '1999': '4.1',
#    '2000': '7',
#    '2001': '3',
#    '2002': '0.7',
#    '2003': '2.5',
#    '2004': '4.6',
#    '2005': '4.4',
#    '2006': '6.3',
#    '2007': '4.5',
#    '2008': '2.8',
#    '2009': '-4.1',
#    '2010': '3.1',
#    '2011': '5',
#    '2012': '3.8',
#    '2013': '0.1',
#    '2014': '4.3',
#    '2015': '4',
#    '2016': '2',
#    '2017': '4.2',
#    '2018': '4.6',
#    '2019': '4.2',
#    '2020': '6.2',
#    '2021': '9',
#    '2022': '2.8',
#    '2023': '5.5'},
#   'PerCapitaIncomeChangePercentile': {'Value': 59.480519480519476},
#   'PerCapitaIncomeChange5Years': {'Value': '5.5'},
#   'PerCapitaIncomeChange5YearsPercentile': {'Value': 52.98701298701298},
#   'PerCapitaIncomeChange10Years': {'Value': '4.7'},
#   'PerCapitaIncomeChange10YearsPercentile': {'Value': 71.42857142857142},
#   'PerCapitaIncomeChange20Years': {'Value': '3.8'},
#   'PerCapitaIncomeChange20YearsPercentile': {'Value': 62.59740259740259},
#   'PerCapitaIncomeChange30Years': {'Value': '3.9'},
#   'PerCapitaIncomeChange30YearsPercentile': {'Value': 58.7012987012987}},
#  {'GeoFips': '10180',
#   'GeoName': 'Abilene, TX (Metropolitan Statistical Area)',
#   'Population': {'1969': '125138',
#    '1970': '122505',
#    '1971': '124841',
#    '1972': '128517',
#    '1973': '127533',
#    '1974': '128625',
#    '1975': '131031',
#    '1976': '133379',
#    '1977': '133052',
#    '1978': '134462',
#    '1979': '136601',
#    '1980': '140098',
#    '1981': '143310',
#    '1982': '148899',
#    '1983': '152939',
#    '1984': '153587',
#    '1985': '153470',
#    '1986': '155031',
#    '1987': '153655',
#    '1988': '150042',
#    '1989': '149324',
#    '1990': '147834',
#    '1991': '147400',
#    '1992': '149917',
#    '1993': '152909',
#    '1994': '153779',
#    '1995': '156097',
#    '1996': '156351',
#    '1997': '157405',
#    '1998': '158264',
#    '1999': '159755',
#    '2000': '160288',
#    '2001': '158917',
#    '2002': '159012',
#    '2003': '158810',
#    '2004': '160156',
#    '2005': '160761',
#    '2006': '161389',
#    '2007': '162023',
#    '2008': '162508',
#    '2009': '163888',
#    '2010': '165673',
#    '2011': '167069',
#    '2012': '168246',
#    '2013': '168614',
#    '2014': '169859',
#    '2015': '171579',
#    '2016': '172242',
#    '2017': '172915',
#    '2018': '174005',
#    '2019': '175187',
#    '2020': '176883',
#    '2021': '177831',
#    '2022': '179665',
#    '2023': '181591'},
#   'PopulationChange5Years': {'Value': '0.9'},
#   'PopulationChange5YearsPercentile': {'Value': 73.76623376623375},
#   'PopulationChange10Years': {'Value': '0.7'},
#   'PopulationChange10YearsPercentile': {'Value': 62.59740259740259},
#   'GeneralPriceIndex': {'Value': '91.738'},
#   'GeneralPriceIndexPercentile': {'Value': 41.298701298701296},
#   'HousingPriceIndex': {'Value': '75.409'},
#   'HousingPriceIndexPercentile': {'Value': 44.15584415584415},
#   'PerCapitaIncome': {'1969': '3176',
#    '1970': '3634',
#    '1971': '3813',
#    '1972': '4212',
#    '1973': '4560',
#    '1974': '5099',
#    '1975': '5889',
#    '1976': '6394',
#    '1977': '6965',
#    '1978': '7901',
#    '1979': '8858',
#    '1980': '9973',
#    '1981': '11733',
#    '1982': '12120',
#    '1983': '12363',
#    '1984': '13082',
#    '1985': '13934',
#    '1986': '13729',
#    '1987': '13605',
#    '1988': '14575',
#    '1989': '15214',
#    '1990': '15722',
#    '1991': '16182',
#    '1992': '16941',
#    '1993': '17427',
#    '1994': '17695',
#    '1995': '18654',
#    '1996': '19829',
#    '1997': '21119',
#    '1998': '21939',
#    '1999': '22592',
#    '2000': '23081',
#    '2001': '23795',
#    '2002': '24851',
#    '2003': '26458',
#    '2004': '27410',
#    '2005': '28776',
#    '2006': '30450',
#    '2007': '31933',
#    '2008': '35228',
#    '2009': '33490',
#    '2010': '34935',
#    '2011': '36812',
#    '2012': '38138',
#    '2013': '39123',
#    '2014': '41461',
#    '2015': '39866',
#    '2016': '39163',
#    '2017': '40384',
#    '2018': '42781',
#    '2019': '45075',
#    '2020': '47854',
#    '2021': '51995',
#    '2022': '53514',
#    '2023': '56034'},
#   'PerCapitaIncomePercentile': {'Value': 37.662337662337656},
#   'PerCapitaIncomeChange': {'1970': '14.4',
#    '1971': '4.9',
#    '1972': '10.5',
#    '1973': '8.3',
#    '1974': '11.8',
#    '1975': '15.5',
#    '1976': '8.6',
#    '1977': '8.9',
#    '1978': '13.4',
#    '1979': '12.1',
#    '1980': '12.6',
#    '1981': '17.6',
#    '1982': '3.3',
#    '1983': '2',
#    '1984': '5.8',
#    '1985': '6.5',
#    '1986': '-1.5',
#    '1987': '-0.9',
#    '1988': '7.1',
#    '1989': '4.4',
#    '1990': '3.3',
#    '1991': '2.9',
#    '1992': '4.7',
#    '1993': '2.9',
#    '1994': '1.5',
#    '1995': '5.4',
#    '1996': '6.3',
#    '1997': '6.5',
#    '1998': '3.9',
#    '1999': '3',
#    '2000': '2.2',
#    '2001': '3.1',
#    '2002': '4.4',
#    '2003': '6.5',
#    '2004': '3.6',
#    '2005': '5',
#    '2006': '5.8',
#    '2007': '4.9',
#    '2008': '10.3',
#    '2009': '-4.9',
#    '2010': '4.3',
#    '2011': '5.4',
#    '2012': '3.6',
#    '2013': '2.6',
#    '2014': '6',
#    '2015': '-3.8',
#    '2016': '-1.8',
#    '2017': '3.1',
#    '2018': '5.9',
#    '2019': '5.4',
#    '2020': '6.2',
#    '2021': '8.7',
#    '2022': '2.9',
#    '2023': '4.7'},
#   'PerCapitaIncomeChangePercentile': {'Value': 32.72727272727273},
#   'PerCapitaIncomeChange5Years': {'Value': '5.5'},
#   'PerCapitaIncomeChange5YearsPercentile': {'Value': 52.98701298701298},
#   'PerCapitaIncomeChange10Years': {'Value': '3.7'},
#   'PerCapitaIncomeChange10YearsPercentile': {'Value': 14.285714285714285},
#   'PerCapitaIncomeChange20Years': {'Value': '3.8'},
#   'PerCapitaIncomeChange20YearsPercentile': {'Value': 62.59740259740259},
#   'PerCapitaIncomeChange30Years': {'Value': '4'},
#   'PerCapitaIncomeChange30YearsPercentile': {'Value': 71.16883116883116}},
#  {'GeoFips': '10420',
#   'GeoName': 'Akron, OH (Metropolitan Statistical Area)',
#   'Population': {'1969': '676214',
#    '1970': '679077',
#    '1971': '679231',
#    '1972': '677046',
#    '1973': '676196',
#    '1974': '670284',
#    '1975': '672844',
#    '1976': '667910',
#    '1977': '662233',
#    '1978': '658517',
#    '1979': '660364',
#    '1980': '660334',
#    '1981': '658870',
#    '1982': '656126',
#    '1983': '653968',
#    '1984': '651917',
#    '1985': '648457',
#    '1986': '646647',
#    '1987': '647810',
#    '1988': '652814',
#    '1989': '655626',
#    '1990': '658654',
#    '1991': '664478',
#    '1992': '669752',
#    '1993': '674114',
#    '1994': '678063',
#    '1995': '682146',
#    '1996': '687264',
#    '1997': '689461',
#    '1998': '691039',
#    '1999': '693125',
#    '2000': '695946',
#    '2001': '698108',
#    '2002': '699533',
#    '2003': '701139',
#    '2004': '701811',
#    '2005': '702498',
#    '2006': '702433',
#    '2007': '703423',
#    '2008': '703300',
#    '2009': '703361',
#    '2010': '703057',
#    '2011': '703272',
#    '2012': '702245',
#    '2013': '703809',
#    '2014': '705134',
#    '2015': '704664',
#    '2016': '703862',
#    '2017': '704229',
#    '2018': '703925',
#    '2019': '703361',
#    '2020': '701674',
#    '2021': '696512',
#    '2022': '697511',
#    '2023': '698398'},
#   'PopulationChange5Years': {'Value': '-0.2'},
#   'PopulationChange5YearsPercentile': {'Value': 17.92207792207792},
#   'PopulationChange10Years': {'Value': '-0.1'},
#   'PopulationChange10YearsPercentile': {'Value': 17.66233766233766},
#   'GeneralPriceIndex': {'Value': '92.059'},
#   'GeneralPriceIndexPercentile': {'Value': 44.41558441558441},
#   'HousingPriceIndex': {'Value': '76.598'},
#   'HousingPriceIndexPercentile': {'Value': 47.01298701298701},
#   'PerCapitaIncome': {'1969': '4024',
#    '1970': '4180',
#    '1971': '4403',
#    '1972': '4820',
#    '1973': '5278',
#    '1974': '5793',
#    '1975': '6115',
#    '1976': '6625',
#    '1977': '7467',
#    '1978': '8309',
#    '1979': '9105',
#    '1980': '10010',
#    '1981': '10988',
#    '1982': '11540',
#    '1983': '12217',
#    '1984': '13334',
#    '1985': '14196',
#    '1986': '14895',
#    '1987': '15530',
#    '1988': '16488',
#    '1989': '17888',
#    '1990': '18815',
#    '1991': '19127',
#    '1992': '20255',
#    '1993': '21018',
#    '1994': '22198',
#    '1995': '23420',
#    '1996': '24433',
#    '1997': '25728',
#    '1998': '27305',
#    '1999': '28079',
#    '2000': '29624',
#    '2001': '30126',
#    '2002': '30521',
#    '2003': '31643',
#    '2004': '32818',
#    '2005': '33619',
#    '2006': '34952',
#    '2007': '36611',
#    '2008': '38358',
#    '2009': '37087',
#    '2010': '38080',
#    '2011': '39794',
#    '2012': '41099',
#    '2013': '41643',
#    '2014': '43331',
#    '2015': '44674',
#    '2016': '45463',
#    '2017': '47163',
#    '2018': '49091',
#    '2019': '50905',
#    '2020': '54376',
#    '2021': '59583',
#    '2022': '59609',
#    '2023': '62904'},
#   'PerCapitaIncomePercentile': {'Value': 65.97402597402596},
#   'PerCapitaIncomeChange': {'1970': '3.9',
#    '1971': '5.3',
#    '1972': '9.5',
#    '1973': '9.5',
#    '1974': '9.8',
#    '1975': '5.6',
#    '1976': '8.3',
#    '1977': '12.7',
#    '1978': '11.3',
#    '1979': '9.6',
#    '1980': '9.9',
#    '1981': '9.8',
#    '1982': '5',
#    '1983': '5.9',
#    '1984': '9.1',
#    '1985': '6.5',
#    '1986': '4.9',
#    '1987': '4.3',
#    '1988': '6.2',
#    '1989': '8.5',
#    '1990': '5.2',
#    '1991': '1.7',
#    '1992': '5.9',
#    '1993': '3.8',
#    '1994': '5.6',
#    '1995': '5.5',
#    '1996': '4.3',
#    '1997': '5.3',
#    '1998': '6.1',
#    '1999': '2.8',
#    '2000': '5.5',
#    '2001': '1.7',
#    '2002': '1.3',
#    '2003': '3.7',
#    '2004': '3.7',
#    '2005': '2.4',
#    '2006': '4',
#    '2007': '4.7',
#    '2008': '4.8',
#    '2009': '-3.3',
#    '2010': '2.7',
#    '2011': '4.5',
#    '2012': '3.3',
#    '2013': '1.3',
#    '2014': '4.1',
#    '2015': '3.1',
#    '2016': '1.8',
#    '2017': '3.7',
#    '2018': '4.1',
#    '2019': '3.7',
#    '2020': '6.8',
#    '2021': '9.6',
#    '2022': '0',
#    '2023': '5.5'},
#   'PerCapitaIncomeChangePercentile': {'Value': 59.480519480519476},
#   'PerCapitaIncomeChange5Years': {'Value': '5.1'},
#   'PerCapitaIncomeChange5YearsPercentile': {'Value': 31.688311688311686},
#   'PerCapitaIncomeChange10Years': {'Value': '4.2'},
#   'PerCapitaIncomeChange10YearsPercentile': {'Value': 44.15584415584415},
#   'PerCapitaIncomeChange20Years': {'Value': '3.5'},
#   'PerCapitaIncomeChange20YearsPercentile': {'Value': 26.233766233766232},
#   'PerCapitaIncomeChange30Years': {'Value': '3.7'},
#   'PerCapitaIncomeChange30YearsPercentile': {'Value': 33.506493506493506}},
#  {'GeoFips': '10500',
#   'GeoName': 'Albany, GA (Metropolitan Statistical Area)',
#   'Population': {'1969': '120767',
#    '1970': '123598',
#    '1971': '127456',
#    '1972': '131775',
#    '1973': '133860',
#    '1974': '130309',
#    '1975': '131861',
#    '1976': '134378',
#    '1977': '137462',
#    '1978': '138191',
#    '1979': '140660',
#    '1980': '142986',
#    '1981': '144771',
#    '1982': '145744',
#    '1983': '145846',
#    '1984': '146534',
#    '1985': '147235',
#    '1986': '146612',
#    '1987': '145828',
#    '1988': '144961',
#    '1989': '144058',
#    '1990': '143025',
#    '1991': '144169',
#    '1992': '146343',
#    '1993': '148122',
#    '1994': '149356',
#    '1995': '150100',
#    '1996': '151596',
#    '1997': '152692',
#    '1998': '153449',
#    '1999': '153555',
#    '2000': '153585',
#    '2001': '153730',
#    '2002': '153024',
#    '2003': '152790',
#    '2004': '152887',
#    '2005': '152919',
#    '2006': '153535',
#    '2007': '153661',
#    '2008': '153823',
#    '2009': '154409',
#    '2010': '154227',
#    '2011': '154933',
#    '2012': '154669',
#    '2013': '153680',
#    '2014': '153263',
#    '2015': '152018',
#    '2016': '151044',
#    '2017': '150387',
#    '2018': '150440',
#    '2019': '149530',
#    '2020': '148249',
#    '2021': '144933',
#    '2022': '145796',
#    '2023': '145508'},
#   'PopulationChange5Years': {'Value': '-0.7'},
#   'PopulationChange5YearsPercentile': {'Value': 3.8961038961038956},
#   'PopulationChange10Years': {'Value': '-0.5'},
#   'PopulationChange10YearsPercentile': {'Value': 4.675324675324675},
#   'GeneralPriceIndex': {'Value': '86.392'},
#   'GeneralPriceIndexPercentile': {'Value': 4.675324675324675},
#   'HousingPriceIndex': {'Value': '50.431'},
#   'HousingPriceIndexPercentile': {'Value': 2.5974025974025974},
#   'PerCapitaIncome': {'1969': '2659',
#    '1970': '3011',
#    '1971': '3329',
#    '1972': '3643',
#    '1973': '4147',
#    '1974': '4397',
#    '1975': '4565',
#    '1976': '4980',
#    '1977': '5319',
#    '1978': '6102',
#    '1979': '6713',
#    '1980': '7370',
#    '1981': '8298',
#    '1982': '8716',
#    '1983': '9274',
#    '1984': '10288',
#    '1985': '10764',
#    '1986': '11275',
#    '1987': '11707',
#    '1988': '12663',
#    '1989': '13640',
#    '1990': '14639',
#    '1991': '15498',
#    '1992': '16012',
#    '1993': '16564',
#    '1994': '17942',
#    '1995': '18824',
#    '1996': '19822',
#    '1997': '20276',
#    '1998': '20986',
#    '1999': '21537',
#    '2000': '22392',
#    '2001': '22873',
#    '2002': '23899',
#    '2003': '24805',
#    '2004': '25402',
#    '2005': '26231',
#    '2006': '26717',
#    '2007': '27800',
#    '2008': '28949',
#    '2009': '29452',
#    '2010': '30317',
#    '2011': '32256',
#    '2012': '32379',
#    '2013': '32211',
#    '2014': '33110',
#    '2015': '33868',
#    '2016': '34476',
#    '2017': '35338',
#    '2018': '36158',
#    '2019': '37940',
#    '2020': '42071',
#    '2021': '46969',
#    '2022': '46754',
#    '2023': '48546'},
#   'PerCapitaIncomePercentile': {'Value': 10.38961038961039},
#   'PerCapitaIncomeChange': {'1970': '13.2',
#    '1971': '10.6',
#    '1972': '9.4',
#    '1973': '13.8',
#    '1974': '6',
#    '1975': '3.8',
#    '1976': '9.1',
#    '1977': '6.8',
#    '1978': '14.7',
#    '1979': '10',
#    '1980': '9.8',
#    '1981': '12.6',
#    '1982': '5',
#    '1983': '6.4',
#    '1984': '10.9',
#    '1985': '4.6',
#    '1986': '4.7',
#    '1987': '3.8',
#    '1988': '8.2',
#    '1989': '7.7',
#    '1990': '7.3',
#    '1991': '5.9',
#    '1992': '3.3',
#    '1993': '3.4',
#    '1994': '8.3',
#    '1995': '4.9',
#    '1996': '5.3',
#    '1997': '2.3',
#    '1998': '3.5',
#    '1999': '2.6',
#    '2000': '4',
#    '2001': '2.1',
#    '2002': '4.5',
#    '2003': '3.8',
#    '2004': '2.4',
#    '2005': '3.3',
#    '2006': '1.9',
#    '2007': '4.1',
#    '2008': '4.1',
#    '2009': '1.7',
#    '2010': '2.9',
#    '2011': '6.4',
#    '2012': '0.4',
#    '2013': '-0.5',
#    '2014': '2.8',
#    '2015': '2.3',
#    '2016': '1.8',
#    '2017': '2.5',
#    '2018': '2.3',
#    '2019': '4.9',
#    '2020': '10.9',
#    '2021': '11.6',
#    '2022': '-0.5',
#    '2023': '3.8'},
#   'PerCapitaIncomeChangePercentile': {'Value': 15.064935064935064},
#   'PerCapitaIncomeChange5Years': {'Value': '6.1'},
#   'PerCapitaIncomeChange5YearsPercentile': {'Value': 82.07792207792207},
#   'PerCapitaIncomeChange10Years': {'Value': '4.2'},
#   'PerCapitaIncomeChange10YearsPercentile': {'Value': 44.15584415584415},
#   'PerCapitaIncomeChange20Years': {'Value': '3.4'},
#   'PerCapitaIncomeChange20YearsPercentile': {'Value': 20.519480519480517},
#   'PerCapitaIncomeChange30Years': {'Value': '3.6'},
#   'PerCapitaIncomeChange30YearsPercentile': {'Value': 21.038961038961038}},
#  {'GeoFips': '10540',
#   'GeoName': 'Albany-Lebanon, OR (Metropolitan Statistical Area)',
#   'Population': {'1969': '70221',
#    '1970': '72587',
#    '1971': '75547',
#    '1972': '76467',
#    '1973': '78150',
#    '1974': '79006',
#    '1975': '80942',
#    '1976': '82420',
#    '1977': '84723',
#    '1978': '86334',
#    '1979': '88999',
#    '1980': '89668',
#    '1981': '90173',
#    '1982': '89748',
#    '1983': '89415',
#    '1984': '89253',
#    '1985': '88019',
#    '1986': '88026',
#    '1987': '88069',
#    '1988': '89223',
#    '1989': '89890',
#    '1990': '91690',
#    '1991': '93145',
#    '1992': '94112',
#    '1993': '95496',
#    '1994': '96919',
#    '1995': '98853',
#    '1996': '100582',
#    '1997': '102054',
#    '1998': '102770',
#    '1999': '103462',
#    '2000': '103020',
#    '2001': '103544',
#    '2002': '104561',
#    '2003': '106035',
#    '2004': '106799',
#    '2005': '108132',
#    '2006': '110764',
#    '2007': '112932',
#    '2008': '114967',
#    '2009': '116001',
#    '2010': '116840',
#    '2011': '117938',
#    '2012': '117865',
#    '2013': '117822',
#    '2014': '118285',
#    '2015': '119295',
#    '2016': '121648',
#    '2017': '123657',
#    '2018': '125788',
#    '2019': '127700',
#    '2020': '128981',
#    '2021': '130120',
#    '2022': '130622',
#    '2023': '131496'},
#   'PopulationChange5Years': {'Value': '0.9'},
#   'PopulationChange5YearsPercentile': {'Value': 73.76623376623375},
#   'PopulationChange10Years': {'Value': '1.1'},
#   'PopulationChange10YearsPercentile': {'Value': 76.62337662337661},
#   'GeneralPriceIndex': {'Value': '104.616'},
#   'GeneralPriceIndexPercentile': {'Value': 88.05194805194805},
#   'HousingPriceIndex': {'Value': '98.988'},
#   'HousingPriceIndexPercentile': {'Value': 75.58441558441558},
#   'PerCapitaIncome': {'1969': '3207',
#    '1970': '3347',
#    '1971': '3560',
#    '1972': '3902',
#    '1973': '4425',
#    '1974': '5014',
#    '1975': '5315',
#    '1976': '6029',
#    '1977': '6633',
#    '1978': '7253',
#    '1979': '7777',
#    '1980': '8516',
#    '1981': '9248',
#    '1982': '9559',
#    '1983': '10118',
#    '1984': '10878',
#    '1985': '11504',
#    '1986': '11988',
#    '1987': '12683',
#    '1988': '13975',
#    '1989': '14935',
#    '1990': '15435',
#    '1991': '16048',
#    '1992': '16871',
#    '1993': '17786',
#    '1994': '18545',
#    '1995': '19399',
#    '1996': '20761',
#    '1997': '21134',
#    '1998': '21571',
#    '1999': '21887',
#    '2000': '22828',
#    '2001': '24753',
#    '2002': '25269',
#    '2003': '25511',
#    '2004': '27047',
#    '2005': '27727',
#    '2006': '29531',
#    '2007': '30300',
#    '2008': '30913',
#    '2009': '30633',
#    '2010': '31609',
#    '2011': '32316',
#    '2012': '33264',
#    '2013': '33705',
#    '2014': '35888',
#    '2015': '37940',
#    '2016': '38991',
#    '2017': '40571',
#    '2018': '43056',
#    '2019': '44286',
#    '2020': '48033',
#    '2021': '52230',
#    '2022': '54123',
#    '2023': '57016'},
#   'PerCapitaIncomePercentile': {'Value': 42.857142857142854},
#   'PerCapitaIncomeChange': {'1970': '4.4',
#    '1971': '6.4',
#    '1972': '9.6',
#    '1973': '13.4',
#    '1974': '13.3',
#    '1975': '6',
#    '1976': '13.4',
#    '1977': '10',
#    '1978': '9.3',
#    '1979': '7.2',
#    '1980': '9.5',
#    '1981': '8.6',
#    '1982': '3.4',
#    '1983': '5.8',
#    '1984': '7.5',
#    '1985': '5.8',
#    '1986': '4.2',
#    '1987': '5.8',
#    '1988': '10.2',
#    '1989': '6.9',
#    '1990': '3.3',
#    '1991': '4',
#    '1992': '5.1',
#    '1993': '5.4',
#    '1994': '4.3',
#    '1995': '4.6',
#    '1996': '7',
#    '1997': '1.8',
#    '1998': '2.1',
#    '1999': '1.5',
#    '2000': '4.3',
#    '2001': '8.4',
#    '2002': '2.1',
#    '2003': '1',
#    '2004': '6',
#    '2005': '2.5',
#    '2006': '6.5',
#    '2007': '2.6',
#    '2008': '2',
#    '2009': '-0.9',
#    '2010': '3.2',
#    '2011': '2.2',
#    '2012': '2.9',
#    '2013': '1.3',
#    '2014': '6.5',
#    '2015': '5.7',
#    '2016': '2.8',
#    '2017': '4.1',
#    '2018': '6.1',
#    '2019': '2.9',
#    '2020': '8.5',
#    '2021': '8.7',
#    '2022': '3.6',
#    '2023': '5.3'},
#   'PerCapitaIncomeChangePercentile': {'Value': 51.688311688311686},
#   'PerCapitaIncomeChange5Years': {'Value': '5.8'},
#   'PerCapitaIncomeChange5YearsPercentile': {'Value': 68.3116883116883},
#   'PerCapitaIncomeChange10Years': {'Value': '5.4'},
#   'PerCapitaIncomeChange10YearsPercentile': {'Value': 89.6103896103896},
#   'PerCapitaIncomeChange20Years': {'Value': '4.1'},
#   'PerCapitaIncomeChange20YearsPercentile': {'Value': 82.85714285714285},
#   'PerCapitaIncomeChange30Years': {'Value': '4'},
#   'PerCapitaIncomeChange30YearsPercentile': {'Value': 71.16883116883116}},
#  {'GeoFips': '10580',
#   'GeoName': 'Albany-Schenectady-Troy, NY (Metropolitan Statistical Area)',
#   'Population': {'1969': '741040',
#    '1970': '749695',
#    '1971': '761289',
#    '1972': '772468',
#    '1973': '774486',
#    '1974': '772691',
#    '1975': '774345',
#    '1976': '772927',
#    '1977': '774635',
#    '1978': '776648',
#    '1979': '776196',
#    '1980': '771823',
#    '1981': '772505',
#    '1982': '773678',
#    '1983': '777649',
#    '1984': '779804',
#    '1985': '783736',
#    '1986': '788761',
#    '1987': '791466',
#    '1988': '798121',
#    '1989': '803919',
#    '1990': '811352',
#    '1991': '818272',
#    '1992': '824285',
#    '1993': '827812',
#    '1994': '830817',
#    '1995': '830439',
#    '1996': '828007',
#    '1997': '824711',
#    '1998': '823712',
#    '1999': '824119',
#    '2000': '827399',
#    '2001': '831034',
#    '2002': '836753',
#    '2003': '844619',
#    '2004': '850384',
#    '2005': '854604',
#    '2006': '860365',
#    '2007': '863068',
#    '2008': '866282',
#    '2009': '869361',
#    '2010': '871603',
#    '2011': '875387',
#    '2012': '879397',
#    '2013': '883854',
#    '2014': '886981',
#    '2015': '889918',
#    '2016': '892762',
#    '2017': '897172',
#    '2018': '899605',
#    '2019': '898791',
#    '2020': '899724',
#    '2021': '904824',
#    '2022': '903595',
#    '2023': '904682'},
#   'PopulationChange5Years': {'Value': '0.1'},
#   'PopulationChange5YearsPercentile': {'Value': 33.506493506493506},
#   'PopulationChange10Years': {'Value': '0.2'},
#   'PopulationChange10YearsPercentile': {'Value': 33.506493506493506},
#   'GeneralPriceIndex': {'Value': '96.563'},
#   'GeneralPriceIndexPercentile': {'Value': 69.87012987012986},
#   'HousingPriceIndex': {'Value': '92.49'},
#   'HousingPriceIndexPercentile': {'Value': 70.38961038961038},
#   'PerCapitaIncome': {'1969': '4002',
#    '1970': '4401',
#    '1971': '4792',
#    '1972': '5082',
#    '1973': '5462',
#    '1974': '5938',
#    '1975': '6409',
#    '1976': '6861',
#    '1977': '7399',
#    '1978': '8071',
#    '1979': '8882',
#    '1980': '9985',
#    '1981': '11057',
#    '1982': '12098',
#    '1983': '12976',
#    '1984': '14305',
#    '1985': '15289',
#    '1986': '16352',
#    '1987': '17244',
#    '1988': '18619',
#    '1989': '20396',
#    '1990': '21380',
#    '1991': '21926',
#    '1992': '23031',
#    '1993': '23656',
#    '1994': '24340',
#    '1995': '25139',
#    '1996': '25986',
#    '1997': '27580',
#    '1998': '29004',
#    '1999': '30434',
#    '2000': '32510',
#    '2001': '33798',
#    '2002': '33865',
#    '2003': '34731',
#    '2004': '36000',
#    '2005': '36908',
#    '2006': '38624',
#    '2007': '40209',
#    '2008': '42442',
#    '2009': '42625',
#    '2010': '44146',
#    '2011': '45558',
#    '2012': '46708',
#    '2013': '47434',
#    '2014': '48762',
#    '2015': '51103',
#    '2016': '51996',
#    '2017': '54685',
#    '2018': '56159',
#    '2019': '58330',
#    '2020': '62728',
#    '2021': '66929',
#    '2022': '67884',
#    '2023': '71972'},
#   'PerCapitaIncomePercentile': {'Value': 84.93506493506493},
#   'PerCapitaIncomeChange': {'1970': '10',
#    '1971': '8.9',
#    '1972': '6.1',
#    '1973': '7.5',
#    '1974': '8.7',
#    '1975': '7.9',
#    '1976': '7.1',
#    '1977': '7.8',
#    '1978': '9.1',
#    '1979': '10',
#    '1980': '12.4',
#    '1981': '10.7',
#    '1982': '9.4',
#    '1983': '7.3',
#    '1984': '10.2',
#    '1985': '6.9',
#    '1986': '7',
#    '1987': '5.5',
#    '1988': '8',
#    '1989': '9.5',
#    '1990': '4.8',
#    '1991': '2.6',
#    '1992': '5',
#    '1993': '2.7',
#    '1994': '2.9',
#    '1995': '3.3',
#    '1996': '3.4',
#    '1997': '6.1',
#    '1998': '5.2',
#    '1999': '4.9',
#    '2000': '6.8',
#    '2001': '4',
#    '2002': '0.2',
#    '2003': '2.6',
#    '2004': '3.7',
#    '2005': '2.5',
#    '2006': '4.6',
#    '2007': '4.1',
#    '2008': '5.6',
#    '2009': '0.4',
#    '2010': '3.6',
#    '2011': '3.2',
#    '2012': '2.5',
#    '2013': '1.6',
#    '2014': '2.8',
#    '2015': '4.8',
#    '2016': '1.7',
#    '2017': '5.2',
#    '2018': '2.7',
#    '2019': '3.9',
#    '2020': '7.5',
#    '2021': '6.7',
#    '2022': '1.4',
#    '2023': '6'},
#   'PerCapitaIncomeChangePercentile': {'Value': 76.10389610389609},
#   'PerCapitaIncomeChange5Years': {'Value': '5.1'},
#   'PerCapitaIncomeChange5YearsPercentile': {'Value': 31.688311688311686},
#   'PerCapitaIncomeChange10Years': {'Value': '4.3'},
#   'PerCapitaIncomeChange10YearsPercentile': {'Value': 49.35064935064935},
#   'PerCapitaIncomeChange20Years': {'Value': '3.7'},
#   'PerCapitaIncomeChange20YearsPercentile': {'Value': 51.94805194805194},
#   'PerCapitaIncomeChange30Years': {'Value': '3.8'},
#   'PerCapitaIncomeChange30YearsPercentile': {'Value': 48.051948051948045}},
#  {'GeoFips': '10740',
#   'GeoName': 'Albuquerque, NM (Metropolitan Statistical Area) *',
#   'Population': {'1969': '377600',
#    '1970': '382076',
#    '1971': '397496',
#    '1972': '407732',
#    '1973': '426583',
#    '1974': '440633',
#    '1975': '450712',
#    '1976': '464570',
#    '1977': '481349',
#    '1978': '492914',
#    '1979': '508581',
#    '1980': '525593',
#    '1981': '534415',
#    '1982': '511169',
#    '1983': '522356',
#    '1984': '533544',
#    '1985': '544603',
#    '1986': '558859',
#    '1987': '574324',
#    '1988': '583976',
#    '1989': '594036',
#    '1990': '602588',
#    '1991': '616345',
#    '1992': '633032',
#    '1993': '649987',
#    '1994': '669734',
#    '1995': '687901',
#    '1996': '700161',
#    '1997': '709661',
#    '1998': '717406',
#    '1999': '722692',
#    '2000': '732220',
#    '2001': '741932',
#    '2002': '757716',
#    '2003': '772128',
#    '2004': '789237',
#    '2005': '809551',
#    '2006': '831252',
#    '2007': '849641',
#    '2008': '863383',
#    '2009': '876448',
#    '2010': '889434',
#    '2011': '897378',
#    '2012': '900747',
#    '2013': '903185',
#    '2014': '902178',
#    '2015': '903085',
#    '2016': '905774',
#    '2017': '908217',
#    '2018': '910284',
#    '2019': '913231',
#    '2020': '917579',
#    '2021': '919392',
#    '2022': '920138',
#    '2023': '922296'},
#   'PopulationChange5Years': {'Value': '0.3'},
#   'PopulationChange5YearsPercentile': {'Value': 45.71428571428571},
#   'PopulationChange10Years': {'Value': '0.2'},
#   'PopulationChange10YearsPercentile': {'Value': 33.506493506493506},
#   'GeneralPriceIndex': {'Value': '93.384'},
#   'GeneralPriceIndexPercentile': {'Value': 54.28571428571428},
#   'HousingPriceIndex': {'Value': '88.663'},
#   'HousingPriceIndexPercentile': {'Value': 65.97402597402596},
#   'PerCapitaIncome': {'1969': '3303',
#    '1970': '3702',
#    '1971': '4021',
#    '1972': '4499',
#    '1973': '4795',
#    '1974': '5203',
#    '1975': '5754',
#    '1976': '6318',
#    '1977': '6832',
#    '1978': '7729',
#    '1979': '8517',
#    '1980': '9247',
#    '1981': '10122',
#    '1982': '11187',
#    '1983': '12041',
#    '1984': '13085',
#    '1985': '14079',
#    '1986': '14617',
#    '1987': '15041',
#    '1988': '15772',
#    '1989': '16468',
#    '1990': '17389',
#    '1991': '18191',
#    '1992': '18997',
#    '1993': '19978',
#    '1994': '21070',
#    '1995': '22091',
#    '1996': '22867',
#    '1997': '23750',
#    '1998': '24527',
#    '1999': '24839',
#    '2000': '26605',
#    '2001': '27672',
#    '2002': '28149',
#    '2003': '28963',
#    '2004': '30161',
#    '2005': '31254',
#    '2006': '32924',
#    '2007': '33770',
#    '2008': '35078',
#    '2009': '34503',
#    '2010': '34521',
#    '2011': '35720',
#    '2012': '35918',
#    '2013': '35330',
#    '2014': '37284',
#    '2015': '38644',
#    '2016': '40050',
#    '2017': '40802',
#    '2018': '42178',
#    '2019': '44597',
#    '2020': '48463',
#    '2021': '52372',
#    '2022': '54687',
#    '2023': '57278'},
#   'PerCapitaIncomePercentile': {'Value': 43.63636363636363},
#   'PerCapitaIncomeChange': {'1970': '12.1',
#    '1971': '8.6',
#    '1972': '11.9',
#    '1973': '6.6',
#    '1974': '8.5',
#    '1975': '10.6',
#    '1976': '9.8',
#    '1977': '8.1',
#    '1978': '13.1',
#    '1979': '10.2',
#    '1980': '8.6',
#    '1981': '9.5',
#    '1982': '10.5',
#    '1983': '7.6',
#    '1984': '8.7',
#    '1985': '7.6',
#    '1986': '3.8',
#    '1987': '2.9',
#    '1988': '4.9',
#    '1989': '4.4',
#    '1990': '5.6',
#    '1991': '4.6',
#    '1992': '4.4',
#    '1993': '5.2',
#    '1994': '5.5',
#    '1995': '4.8',
#    '1996': '3.5',
#    '1997': '3.9',
#    '1998': '3.3',
#    '1999': '1.3',
#    '2000': '7.1',
#    '2001': '4',
#    '2002': '1.7',
#    '2003': '2.9',
#    '2004': '4.1',
#    '2005': '3.6',
#    '2006': '5.3',
#    '2007': '2.6',
#    '2008': '3.9',
#    '2009': '-1.6',
#    '2010': '0.1',
#    '2011': '3.5',
#    '2012': '0.6',
#    '2013': '-1.6',
#    '2014': '5.5',
#    '2015': '3.6',
#    '2016': '3.6',
#    '2017': '1.9',
#    '2018': '3.4',
#    '2019': '5.7',
#    '2020': '8.7',
#    '2021': '8.1',
#    '2022': '4.4',
#    '2023': '4.7'},
#   'PerCapitaIncomeChangePercentile': {'Value': 32.72727272727273},
#   'PerCapitaIncomeChange5Years': {'Value': '6.3'},
#   'PerCapitaIncomeChange5YearsPercentile': {'Value': 87.01298701298701},
#   'PerCapitaIncomeChange10Years': {'Value': '5'},
#   'PerCapitaIncomeChange10YearsPercentile': {'Value': 79.99999999999999},
#   'PerCapitaIncomeChange20Years': {'Value': '3.5'},
#   'PerCapitaIncomeChange20YearsPercentile': {'Value': 26.233766233766232},
#   'PerCapitaIncomeChange30Years': {'Value': '3.6'},
#   'PerCapitaIncomeChange30YearsPercentile': {'Value': 21.038961038961038}},
#  {'GeoFips': '10780',
#   'GeoName': 'Alexandria, LA (Metropolitan Statistical Area)',
#   'Population': {'1969': '131387',
#    '1970': '132287',
#    '1971': '136756',
#    '1972': '137425',
#    '1973': '139971',
#    '1974': '140176',
#    '1975': '141141',
#    '1976': '143786',
#    '1977': '146270',
#    '1978': '147614',
#    '1979': '149880',
#    '1980': '152197',
#    '1981': '152773',
#    '1982': '152877',
#    '1983': '154017',
#    '1984': '154515',
#    '1985': '153989',
#    '1986': '154335',
#    '1987': '153188',
#    '1988': '151377',
#    '1989': '150180',
#    '1990': '148982',
#    '1991': '149046',
#    '1992': '147621',
#    '1993': '142225',
#    '1994': '143086',
#    '1995': '144162',
#    '1996': '143970',
#    '1997': '143986',
#    '1998': '144330',
#    '1999': '144803',
#    '2000': '145179',
#    '2001': '145102',
#    '2002': '145416',
#    '2003': '146017',
#    '2004': '146973',
#    '2005': '147930',
#    '2006': '151142',
#    '2007': '151506',
#    '2008': '152442',
#    '2009': '153164',
#    '2010': '154112',
#    '2011': '154538',
#    '2012': '154643',
#    '2013': '154972',
#    '2014': '155021',
#    '2015': '154658',
#    '2016': '154763',
#    '2017': '154292',
#    '2018': '153614',
#    '2019': '153019',
#    '2020': '151800',
#    '2021': '150882',
#    '2022': '149068',
#    '2023': '148171'},
#   'PopulationChange5Years': {'Value': '-0.7'},
#   'PopulationChange5YearsPercentile': {'Value': 3.8961038961038956},
#   'PopulationChange10Years': {'Value': '-0.4'},
#   'PopulationChange10YearsPercentile': {'Value': 7.012987012987012},
#   'GeneralPriceIndex': {'Value': '86.169'},
#   'GeneralPriceIndexPercentile': {'Value': 3.636363636363636},
#   'HousingPriceIndex': {'Value': '48.026'},
#   'HousingPriceIndexPercentile': {'Value': 1.2987012987012987},
#   'PerCapitaIncome': {'1969': '2816',
#    '1970': '3012',
#    '1971': '3310',
#    '1972': '3595',
#    '1973': '3926',
#    '1974': '4256',
#    '1975': '4726',
#    '1976': '5218',
#    '1977': '5614',
#    '1978': '6314',
#    '1979': '6886',
#    '1980': '7737',
#    '1981': '8574',
#    '1982': '9219',
#    '1983': '9888',
#    '1984': '10435',
#    '1985': '11109',
#    '1986': '11500',
#    '1987': '11920',
#    '1988': '12755',
#    '1989': '13841',
#    '1990': '14814',
#    '1991': '15343',
#    '1992': '16073',
#    '1993': '17624',
#    '1994': '18792',
#    '1995': '19332',
#    '1996': '19890',
#    '1997': '20566',
#    '1998': '21738',
#    '1999': '22435',
#    '2000': '23312',
#    '2001': '25496',
#    '2002': '26351',
#    '2003': '26621',
#    '2004': '28365',
#    '2005': '30774',
#    '2006': '31732',
#    '2007': '33209',
#    '2008': '35092',
#    '2009': '34570',
#    '2010': '34936',
#    '2011': '36684',
#    '2012': '38264',
#    '2013': '38257',
#    '2014': '38665',
#    '2015': '39271',
#    '2016': '39871',
#    '2017': '40302',
#    '2018': '41876',
#    '2019': '43558',
#    '2020': '47669',
#    '2021': '51240',
#    '2022': '51601',
#    '2023': '53765'},
#   'PerCapitaIncomePercentile': {'Value': 29.610389610389607},
#   'PerCapitaIncomeChange': {'1970': '7',
#    '1971': '9.9',
#    '1972': '8.6',
#    '1973': '9.2',
#    '1974': '8.4',
#    '1975': '11',
#    '1976': '10.4',
#    '1977': '7.6',
#    '1978': '12.5',
#    '1979': '9.1',
#    '1980': '12.4',
#    '1981': '10.8',
#    '1982': '7.5',
#    '1983': '7.3',
#    '1984': '5.5',
#    '1985': '6.5',
#    '1986': '3.5',
#    '1987': '3.7',
#    '1988': '7',
#    '1989': '8.5',
#    '1990': '7',
#    '1991': '3.6',
#    '1992': '4.8',
#    '1993': '9.6',
#    '1994': '6.6',
#    '1995': '2.9',
#    '1996': '2.9',
#    '1997': '3.4',
#    '1998': '5.7',
#    '1999': '3.2',
#    '2000': '3.9',
#    '2001': '9.4',
#    '2002': '3.4',
#    '2003': '1',
#    '2004': '6.6',
#    '2005': '8.5',
#    '2006': '3.1',
#    '2007': '4.7',
#    '2008': '5.7',
#    '2009': '-1.5',
#    '2010': '1.1',
#    '2011': '5',
#    '2012': '4.3',
#    '2013': '0',
#    '2014': '1.1',
#    '2015': '1.6',
#    '2016': '1.5',
#    '2017': '1.1',
#    '2018': '3.9',
#    '2019': '4',
#    '2020': '9.4',
#    '2021': '7.5',
#    '2022': '0.7',
#    '2023': '4.2'},
#   'PerCapitaIncomeChangePercentile': {'Value': 20.519480519480517},
#   'PerCapitaIncomeChange5Years': {'Value': '5.1'},
#   'PerCapitaIncomeChange5YearsPercentile': {'Value': 31.688311688311686},
#   'PerCapitaIncomeChange10Years': {'Value': '3.5'},
#   'PerCapitaIncomeChange10YearsPercentile': {'Value': 8.311688311688311},
#   'PerCapitaIncomeChange20Years': {'Value': '3.6'},
#   'PerCapitaIncomeChange20YearsPercentile': {'Value': 38.18181818181818},
#   'PerCapitaIncomeChange30Years': {'Value': '3.8'},
#   'PerCapitaIncomeChange30YearsPercentile': {'Value': 48.051948051948045}},
#  {'GeoFips': '10900',
#   'GeoName': 'Allentown-Bethlehem-Easton, PA-NJ (Metropolitan Statistical Area)',
#   'Population': {'1969': '589204',
#    '1970': '595577',
#    '1971': '601892',
#    '1972': '605156',
#    '1973': '610947',
#    '1974': '617690',
#    '1975': '622114',
#    '1976': '624814',
#    '1977': '627598',
#    '1978': '629719',
#    '1979': '633073',
#    '1980': '636389',
#    '1981': '638748',
#    '1982': '640790',
#    '1983': '641637',
#    '1984': '644843',
#    '1985': '648256',
#    '1986': '654365',
#    '1987': '663413',
#    '1988': '674767',
#    '1989': '682657',
#    '1990': '688801',
#    '1991': '696168',
#    '1992': '702948',
#    '1993': '708776',
#    '1994': '714019',
#    '1995': '717685',
#    '1996': '722063',
#    '1997': '726464',
#    '1998': '730779',
#    '1999': '736327',
#    '2000': '741817',
#    '2001': '748705',
#    '2002': '756628',
#    '2003': '766938',
#    '2004': '777277',
#    '2005': '787738',
#    '2006': '798586',
#    '2007': '807578',
#    '2008': '814050',
#    '2009': '817779',
#    '2010': '822144',
#    '2011': '826750',
#    '2012': '829566',
#    '2013': '830735',
#    '2014': '835077',
#    '2015': '838490',
#    '2016': '843181',
#    '2017': '849703',
#    '2018': '855983',
#    '2019': '858656',
#    '2020': '861557',
#    '2021': '870135',
#    '2022': '870570',
#    '2023': '873555'},
#   'PopulationChange5Years': {'Value': '0.4'},
#   'PopulationChange5YearsPercentile': {'Value': 51.42857142857142},
#   'PopulationChange10Years': {'Value': '0.5'},
#   'PopulationChange10YearsPercentile': {'Value': 49.870129870129865},
#   'GeneralPriceIndex': {'Value': '98.047'},
#   'GeneralPriceIndexPercentile': {'Value': 74.02597402597402},
#   'HousingPriceIndex': {'Value': '102.924'},
#   'HousingPriceIndexPercentile': {'Value': 79.2207792207792},
#   'PerCapitaIncome': {'1969': '3866',
#    '1970': '4148',
#    '1971': '4377',
#    '1972': '4828',
#    '1973': '5390',
#    '1974': '5983',
#    '1975': '6532',
#    '1976': '7076',
#    '1977': '7787',
#    '1978': '8626',
#    '1979': '9573',
#    '1980': '10510',
#    '1981': '11585',
#    '1982': '12376',
#    '1983': '12938',
#    '1984': '14103',
#    '1985': '15017',
#    '1986': '15671',
#    '1987': '16463',
#    '1988': '17616',
#    '1989': '18995',
#    '1990': '19859',
#    '1991': '20624',
#    '1992': '21604',
#    '1993': '22212',
#    '1994': '22855',
#    '1995': '23693',
#    '1996': '24813',
#    '1997': '25968',
#    '1998': '27089',
#    '1999': '28378',
#    '2000': '30364',
#    '2001': '32403',
#    '2002': '33077',
#    '2003': '33804',
#    '2004': '35202',
#    '2005': '37089',
#    '2006': '38379',
#    '2007': '41063',
#    '2008': '42372',
#    '2009': '40845',
#    '2010': '42274',
#    '2011': '43509',
#    '2012': '43937',
#    '2013': '44324',
#    '2014': '45795',
#    '2015': '47682',
#    '2016': '48896',
#    '2017': '50135',
#    '2018': '52126',
#    '2019': '54962',
#    '2020': '58589',
#    '2021': '61836',
#    '2022': '62900',
#    '2023': '66493'},
#   'PerCapitaIncomePercentile': {'Value': 75.32467532467531},
#   'PerCapitaIncomeChange': {'1970': '7.3',
#    '1971': '5.5',
#    '1972': '10.3',
#    '1973': '11.6',
#    '1974': '11',
#    '1975': '9.2',
#    '1976': '8.3',
#    '1977': '10',
#    '1978': '10.8',
#    '1979': '11',
#    '1980': '9.8',
#    '1981': '10.2',
#    '1982': '6.8',
#    '1983': '4.5',
#    '1984': '9',
#    '1985': '6.5',
#    '1986': '4.4',
#    '1987': '5.1',
#    '1988': '7',
#    '1989': '7.8',
#    '1990': '4.5',
#    '1991': '3.9',
#    '1992': '4.8',
#    '1993': '2.8',
#    '1994': '2.9',
#    '1995': '3.7',
#    '1996': '4.7',
#    '1997': '4.7',
#    '1998': '4.3',
#    '1999': '4.8',
#    '2000': '7',
#    '2001': '6.7',
#    '2002': '2.1',
#    '2003': '2.2',
#    '2004': '4.1',
#    '2005': '5.4',
#    '2006': '3.5',
#    '2007': '7',
#    '2008': '3.2',
#    '2009': '-3.6',
#    '2010': '3.5',
#    '2011': '2.9',
#    '2012': '1',
#    '2013': '0.9',
#    '2014': '3.3',
#    '2015': '4.1',
#    '2016': '2.5',
#    '2017': '2.5',
#    '2018': '4',
#    '2019': '5.4',
#    '2020': '6.6',
#    '2021': '5.5',
#    '2022': '1.7',
#    '2023': '5.7'},
#   'PerCapitaIncomeChangePercentile': {'Value': 68.3116883116883},
#   'PerCapitaIncomeChange5Years': {'Value': '5'},
#   'PerCapitaIncomeChange5YearsPercentile': {'Value': 27.53246753246753},
#   'PerCapitaIncomeChange10Years': {'Value': '4.1'},
#   'PerCapitaIncomeChange10YearsPercentile': {'Value': 36.88311688311688},
#   'PerCapitaIncomeChange20Years': {'Value': '3.4'},
#   'PerCapitaIncomeChange20YearsPercentile': {'Value': 20.519480519480517},
#   'PerCapitaIncomeChange30Years': {'Value': '3.7'},
#   'PerCapitaIncomeChange30YearsPercentile': {'Value': 33.506493506493506}},
#  {'GeoFips': '11020',
#   'GeoName': 'Altoona, PA (Metropolitan Statistical Area)',
#   'Population': {'1969': '135488',
#    '1970': '135538',
#    '1971': '136999',
#    '1972': '137687',
#    '1973': '136556',
#    '1974': '136956',
#    '1975': '136611',
#    '1976': '136023',
#    '1977': '137015',
#    '1978': '137705',
#    '1979': '137966',
#    '1980': '136443',
#    '1981': '135457',
#    '1982': '135600',
#    '1983': '134397',
#    '1984': '132925',
#    '1985': '132253',
#    '1986': '131556',
#    '1987': '131712',
#    '1988': '131408',
#    '1989': '130546',
#    '1990': '130593',
#    '1991': '131160',
#    '1992': '131270',
#    '1993': '131661',
#    '1994': '132124',
#    '1995': '131802',
#    '1996': '131080',
#    '1997': '130931',
#    '1998': '130509',
#    '1999': '129757',
#    '2000': '128981',
#    '2001': '128471',
#    '2002': '127631',
#    '2003': '127353',
#    '2004': '127194',
#    '2005': '126730',
#    '2006': '127002',
#    '2007': '127048',
#    '2008': '127112',
#    '2009': '127161',
#    '2010': '127089',
#    '2011': '127192',
#    '2012': '126931',
#    '2013': '126389',
#    '2014': '125986',
#    '2015': '125469',
#    '2016': '124764',
#    '2017': '124310',
#    '2018': '123854',
#    '2019': '123376',
#    '2020': '122666',
#    '2021': '122150',
#    '2022': '120734',
#    '2023': '120273'},
#   'PopulationChange5Years': {'Value': '-0.6'},
#   'PopulationChange5YearsPercentile': {'Value': 5.974025974025974},
#   'PopulationChange10Years': {'Value': '-0.5'},
#   'PopulationChange10YearsPercentile': {'Value': 4.675324675324675},
#   'GeneralPriceIndex': {'Value': '89.014'},
#   'GeneralPriceIndexPercentile': {'Value': 20.77922077922078},
#   'HousingPriceIndex': {'Value': '53.618'},
#   'HousingPriceIndexPercentile': {'Value': 6.493506493506493},
#   'PerCapitaIncome': {'1969': '3181',
#    '1970': '3470',
#    '1971': '3644',
#    '1972': '3891',
#    '1973': '4319',
#    '1974': '4725',
#    '1975': '5220',
#    '1976': '5847',
#    '1977': '6402',
#    '1978': '7013',
#    '1979': '7730',
#    '1980': '8357',
#    '1981': '9085',
#    '1982': '9464',
#    '1983': '9913',
#    '1984': '10629',
#    '1985': '11426',
#    '1986': '12137',
#    '1987': '12553',
#    '1988': '13256',
#    '1989': '14453',
#    '1990': '15309',
#    '1991': '15972',
#    '1992': '17033',
#    '1993': '17837',
#    '1994': '18571',
#    '1995': '19323',
#    '1996': '20485',
#    '1997': '21621',
#    '1998': '22792',
#    '1999': '23775',
#    '2000': '24903',
#    '2001': '25293',
#    '2002': '26170',
#    '2003': '27211',
#    '2004': '28561',
#    '2005': '29653',
#    '2006': '30530',
#    '2007': '32037',
#    '2008': '33289',
#    '2009': '33755',
#    '2010': '35024',
#    '2011': '36961',
#    '2012': '37573',
#    '2013': '37498',
#    '2014': '38992',
#    '2015': '40944',
#    '2016': '41604',
#    '2017': '42754',
#    '2018': '44979',
#    '2019': '46381',
#    '2020': '50793',
#    '2021': '54826',
#    '2022': '55071',
#    '2023': '57782'},
#   'PerCapitaIncomePercentile': {'Value': 46.49350649350649},
#   'PerCapitaIncomeChange': {'1970': '9.1',
#    '1971': '5',
#    '1972': '6.8',
#    '1973': '11',
#    '1974': '9.4',
#    '1975': '10.5',
#    '1976': '12',
#    '1977': '9.5',
#    '1978': '9.5',
#    '1979': '10.2',
#    '1980': '8.1',
#    '1981': '8.7',
#    '1982': '4.2',
#    '1983': '4.7',
#    '1984': '7.2',
#    '1985': '7.5',
#    '1986': '6.2',
#    '1987': '3.4',
#    '1988': '5.6',
#    '1989': '9',
#    '1990': '5.9',
#    '1991': '4.3',
#    '1992': '6.6',
#    '1993': '4.7',
#    '1994': '4.1',
#    '1995': '4',
#    '1996': '6',
#    '1997': '5.5',
#    '1998': '5.4',
#    '1999': '4.3',
#    '2000': '4.7',
#    '2001': '1.6',
#    '2002': '3.5',
#    '2003': '4',
#    '2004': '5',
#    '2005': '3.8',
#    '2006': '3',
#    '2007': '4.9',
#    '2008': '3.9',
#    '2009': '1.4',
#    '2010': '3.8',
#    '2011': '5.5',
#    '2012': '1.7',
#    '2013': '-0.2',
#    '2014': '4',
#    '2015': '5',
#    '2016': '1.6',
#    '2017': '2.8',
#    '2018': '5.2',
#    '2019': '3.1',
#    '2020': '9.5',
#    '2021': '7.9',
#    '2022': '0.4',
#    '2023': '4.9'},
#   'PerCapitaIncomeChangePercentile': {'Value': 37.92207792207792},
#   'PerCapitaIncomeChange5Years': {'Value': '5.1'},
#   'PerCapitaIncomeChange5YearsPercentile': {'Value': 31.688311688311686},
#   'PerCapitaIncomeChange10Years': {'Value': '4.4'},
#   'PerCapitaIncomeChange10YearsPercentile': {'Value': 55.06493506493506},
#   'PerCapitaIncomeChange20Years': {'Value': '3.8'},
#   'PerCapitaIncomeChange20YearsPercentile': {'Value': 62.59740259740259},
#   'PerCapitaIncomeChange30Years': {'Value': '4'},
#   'PerCapitaIncomeChange30YearsPercentile': {'Value': 71.16883116883116}},
#  {'GeoFips': '11100',
#   'GeoName': 'Amarillo, TX (Metropolitan Statistical Area)',
#   'Population': {'1969': '170368',
#    '1970': '155258',
#    '1971': '158182',
#    '1972': '160557',
#    '1973': '161637',
#    '1974': '163395',
#    '1975': '165916',
#    '1976': '169368',
#    '1977': '173027',
#    '1978': '175670',
#    '1979': '181120',
#    '1980': '185546',
#    '1981': '188598',
#    '1982': '192559',
#    '1983': '195720',
#    '1984': '198910',
#    '1985': '199407',
#    '1986': '200618',
#    '1987': '200360',
#    '1988': '201069',
#    '1989': '199721',
#    '1990': '198488',
#    '1991': '200626',
#    '1992': '203371',
#    '1993': '207282',
#    '1994': '211306',
#    '1995': '217400',
#    '1996': '219808',
#    '1997': '222054',
#    '1998': '223545',
#    '1999': '226621',
#    '2000': '229215',
#    '2001': '230351',
#    '2002': '232326',
#    '2003': '235138',
#    '2004': '237566',
#    '2005': '240380',
#    '2006': '242656',
#    '2007': '244608',
#    '2008': '246458',
#    '2009': '249373',
#    '2010': '252739',
#    '2011': '256366',
#    '2012': '258511',
#    '2013': '259908',
#    '2014': '262135',
#    '2015': '263232',
#    '2016': '264785',
#    '2017': '266308',
#    '2018': '266497',
#    '2019': '267174',
#    '2020': '269029',
#    '2021': '269804',
#    '2022': '270589',
#    '2023': '272395'},
#   'PopulationChange5Years': {'Value': '0.4'},
#   'PopulationChange5YearsPercentile': {'Value': 51.42857142857142},
#   'PopulationChange10Years': {'Value': '0.5'},
#   'PopulationChange10YearsPercentile': {'Value': 49.870129870129865},
#   'GeneralPriceIndex': {'Value': '91.776'},
#   'GeneralPriceIndexPercentile': {'Value': 41.81818181818181},
#   'HousingPriceIndex': {'Value': '74.712'},
#   'HousingPriceIndexPercentile': {'Value': 42.59740259740259},
#   'PerCapitaIncome': {'1969': '3268',
#    '1970': '3887',
#    '1971': '4156',
#    '1972': '4375',
#    '1973': '5070',
#    '1974': '5457',
#    '1975': '6633',
#    '1976': '7115',
#    '1977': '7688',
#    '1978': '8568',
#    '1979': '9347',
#    '1980': '10003',
#    '1981': '11354',
#    '1982': '12228',
#    '1983': '13433',
#    '1984': '14024',
#    '1985': '14671',
#    '1986': '14756',
#    '1987': '14984',
#    '1988': '15178',
#    '1989': '16011',
#    '1990': '16816',
#    '1991': '17061',
#    '1992': '18070',
#    '1993': '18891',
#    '1994': '19620',
#    '1995': '20214',
#    '1996': '20886',
#    '1997': '22064',
#    '1998': '22978',
#    '1999': '23299',
#    '2000': '24103',
#    '2001': '26439',
#    '2002': '27054',
#    '2003': '27863',
#    '2004': '28001',
#    '2005': '29494',
#    '2006': '31242',
#    '2007': '33003',
#    '2008': '36684',
#    '2009': '35241',
#    '2010': '38036',
#    '2011': '40070',
#    '2012': '40669',
#    '2013': '41108',
#    '2014': '42723',
#    '2015': '42750',
#    '2016': '42505',
#    '2017': '44042',
#    '2018': '45765',
#    '2019': '48397',
#    '2020': '51696',
#    '2021': '55923',
#    '2022': '56643',
#    '2023': '60182'},
#   'PerCapitaIncomePercentile': {'Value': 56.36363636363636},
#   'PerCapitaIncomeChange': {'1970': '18.9',
#    '1971': '6.9',
#    '1972': '5.3',
#    '1973': '15.9',
#    '1974': '7.6',
#    '1975': '21.6',
#    '1976': '7.3',
#    '1977': '8.1',
#    '1978': '11.4',
#    '1979': '9.1',
#    '1980': '7',
#    '1981': '13.5',
#    '1982': '7.7',
#    '1983': '9.9',
#    '1984': '4.4',
#    '1985': '4.6',
#    '1986': '0.6',
#    '1987': '1.5',
#    '1988': '1.3',
#    '1989': '5.5',
#    '1990': '5',
#    '1991': '1.5',
#    '1992': '5.9',
#    '1993': '4.5',
#    '1994': '3.9',
#    '1995': '3',
#    '1996': '3.3',
#    '1997': '5.6',
#    '1998': '4.1',
#    '1999': '1.4',
#    '2000': '3.5',
#    '2001': '9.7',
#    '2002': '2.3',
#    '2003': '3',
#    '2004': '0.5',
# ...
#    '1970': '4411',
#    '1971': '4587',
#    '1972': '5043',
#    '1973': '5557',
#    '1974': '6036',
#    '1975': '6486',
#    '1976': '7123',
#    '1977': '7852',
#    '1978': '8783',
#    '1979': '9780',
#    '1980': '10830',
#    '1981': '11817',
#    '1982': '12466',
#    '1983': '13041',
#    '1984': '14144',
#    '1985': '15076',
#    '1986': '15874',
#    '1987': '16700',
#    '1988': '17957',
#    '1989': '19194',
#    '1990': '19869',
#    '1991': '20467',
#    '1992': '21407',
#    '1993': '22199',
#    '1994': '22459',
#    '1995': '23365',
#    '1996': '24335',
#    '1997': '25361',
#    '1998': '26486',
#    '1999': '27271',
#    '2000': '29041',
#    '2001': '29855',
#    '2002': '30283',
#    '2003': '31592',
#    '2004': '34297',
#    '2005': '36082',
#    '2006': '36301',
#    '2007': '39060',
#    '2008': '41921',
#    '2009': '40345',
#    '2010': '40662',
#    '2011': '41465',
#    '2012': '41751',
#    '2013': '41745',
#    '2014': '42613',
#    '2015': '44177',
#    '2016': '45488',
#    '2017': '47130',
#    '2018': '49020',
#    '2019': '50687',
#    '2020': '54362',
#    '2021': '57329',
#    '2022': '58305',
#    '2023': '60915'},
#   'PerCapitaIncomePercentile': {'Value': 58.441558441558435},
#   'PerCapitaIncomeChange': {'1970': '8.3',
#    '1971': '4',
#    '1972': '9.9',
#    '1973': '10.2',
#    '1974': '8.6',
#    '1975': '7.5',
#    '1976': '9.8',
#    '1977': '10.2',
#    '1978': '11.9',
#    '1979': '11.4',
#    '1980': '10.7',
#    '1981': '9.1',
#    '1982': '5.5',
#    '1983': '4.6',
#    '1984': '8.5',
#    '1985': '6.6',
#    '1986': '5.3',
#    '1987': '5.2',
#    '1988': '7.5',
#    '1989': '6.9',
#    '1990': '3.5',
#    '1991': '3',
#    '1992': '4.6',
#    '1993': '3.7',
#    '1994': '1.2',
#    '1995': '4',
#    '1996': '4.2',
#    '1997': '4.2',
#    '1998': '4.4',
#    '1999': '3',
#    '2000': '6.5',
#    '2001': '2.8',
#    '2002': '1.4',
#    '2003': '4.3',
#    '2004': '8.6',
#    '2005': '5.2',
#    '2006': '0.6',
#    '2007': '7.6',
#    '2008': '7.3',
#    '2009': '-3.8',
#    '2010': '0.8',
#    '2011': '2',
#    '2012': '0.7',
#    '2013': '0',
#    '2014': '2.1',
#    '2015': '3.7',
#    '2016': '3',
#    '2017': '3.6',
#    '2018': '4',
#    '2019': '3.4',
#    '2020': '7.3',
#    '2021': '5.5',
#    '2022': '1.7',
#    '2023': '4.5'},
#   'PerCapitaIncomeChangePercentile': {'Value': 26.75324675324675},
#   'PerCapitaIncomeChange5Years': {'Value': '4.4'},
#   'PerCapitaIncomeChange5YearsPercentile': {'Value': 7.792207792207791},
#   'PerCapitaIncomeChange10Years': {'Value': '3.9'},
#   'PerCapitaIncomeChange10YearsPercentile': {'Value': 22.337662337662337},
#   'PerCapitaIncomeChange20Years': {'Value': '3.3'},
#   'PerCapitaIncomeChange20YearsPercentile': {'Value': 12.727272727272727},
#   'PerCapitaIncomeChange30Years': {'Value': '3.4'},
#   'PerCapitaIncomeChange30YearsPercentile': {'Value': 8.571428571428571}},
#  {'GeoFips': '49660',
#   'GeoName': 'Youngstown-Warren-Boardman, OH-PA (Metropolitan Statistical Area)',
#   'Population': {'1969': '659506',
#    '1970': '665569',
#    '1971': '670741',
#    '1972': '681278',
#    '1973': '668722',
#    '1974': '675013',
#    '1975': '662274',
#    '1976': '666754',
#    '1977': '667417',
#    '1978': '664956',
#    '1979': '658231',
#    '1980': '658600',
#    '1981': '652946',
#    '1982': '649503',
#    '1983': '644566',
#    '1984': '637279',
#    '1985': '631445',
#    '1986': '625219',
#    '1987': '619212',
#    '1988': '615749',
#    '1989': '615048',
#    '1990': '613980',
#    '1991': '615462',
#    '1992': '617681',
#    '1993': '618328',
#    '1994': '617253',
#    '1995': '615595',
#    '1996': '614369',
#    '1997': '611902',
#    '1998': '609286',
#    '1999': '605978',
#    '2000': '602227',
#    '2001': '599116',
#    '2002': '594958',
#    '2003': '592016',
#    '2004': '588478',
#    '2005': '584222',
#    '2006': '580420',
#    '2007': '575543',
#    '2008': '570952',
#    '2009': '568156',
#    '2010': '564978',
#    '2011': '563424',
#    '2012': '560540',
#    '2013': '558798',
#    '2014': '556915',
#    '2015': '553591',
#    '2016': '550063',
#    '2017': '547497',
#    '2018': '545030',
#    '2019': '542582',
#    '2020': '540240',
#    '2021': '538059',
#    '2022': '535785',
#    '2023': '534472'},
#   'PopulationChange5Years': {'Value': '-0.4'},
#   'PopulationChange5YearsPercentile': {'Value': 10.649350649350648},
#   'PopulationChange10Years': {'Value': '-0.4'},
#   'PopulationChange10YearsPercentile': {'Value': 7.012987012987012},
#   'GeneralPriceIndex': {'Value': '86.64'},
#   'GeneralPriceIndexPercentile': {'Value': 5.454545454545454},
#   'HousingPriceIndex': {'Value': '52.108'},
#   'HousingPriceIndexPercentile': {'Value': 4.1558441558441555},
#   'PerCapitaIncome': {'1969': '3771',
#    '1970': '3886',
#    '1971': '4111',
#    '1972': '4472',
#    '1973': '5143',
#    '1974': '5569',
#    '1975': '6005',
#    '1976': '6560',
#    '1977': '7252',
#    '1978': '7994',
#    '1979': '8899',
#    '1980': '9668',
#    '1981': '10637',
#    '1982': '10673',
#    '1983': '11233',
#    '1984': '12333',
#    '1985': '13007',
#    '1986': '13515',
#    '1987': '13909',
#    '1988': '15191',
#    '1989': '16340',
#    '1990': '16988',
#    '1991': '17402',
#    '1992': '18243',
#    '1993': '18762',
#    '1994': '19730',
#    '1995': '20610',
#    '1996': '21323',
#    '1997': '22369',
#    '1998': '23152',
#    '1999': '23786',
#    '2000': '24781',
#    '2001': '25834',
#    '2002': '26419',
#    '2003': '27467',
#    '2004': '28350',
#    '2005': '29282',
#    '2006': '31061',
#    '2007': '32076',
#    '2008': '33276',
#    '2009': '31798',
#    '2010': '32930',
#    '2011': '35029',
#    '2012': '35722',
#    '2013': '35923',
#    '2014': '37000',
#    '2015': '38143',
#    '2016': '38564',
#    '2017': '39518',
#    '2018': '40924',
#    '2019': '41908',
#    '2020': '45370',
#    '2021': '48878',
#    '2022': '49271',
#    '2023': '51869'},
#   'PerCapitaIncomePercentile': {'Value': 21.818181818181817},
#   'PerCapitaIncomeChange': {'1970': '3',
#    '1971': '5.8',
#    '1972': '8.8',
#    '1973': '15',
#    '1974': '8.3',
#    '1975': '7.8',
#    '1976': '9.2',
#    '1977': '10.5',
#    '1978': '10.2',
#    '1979': '11.3',
#    '1980': '8.6',
#    '1981': '10',
#    '1982': '0.3',
#    '1983': '5.2',
#    '1984': '9.8',
#    '1985': '5.5',
#    '1986': '3.9',
#    '1987': '2.9',
#    '1988': '9.2',
#    '1989': '7.6',
#    '1990': '4',
#    '1991': '2.4',
#    '1992': '4.8',
#    '1993': '2.8',
#    '1994': '5.2',
#    '1995': '4.5',
#    '1996': '3.5',
#    '1997': '4.9',
#    '1998': '3.5',
#    '1999': '2.7',
#    '2000': '4.2',
#    '2001': '4.2',
#    '2002': '2.3',
#    '2003': '4',
#    '2004': '3.2',
#    '2005': '3.3',
#    '2006': '6.1',
#    '2007': '3.3',
#    '2008': '3.7',
#    '2009': '-4.4',
#    '2010': '3.6',
#    '2011': '6.4',
#    '2012': '2',
#    '2013': '0.6',
#    '2014': '3',
#    '2015': '3.1',
#    '2016': '1.1',
#    '2017': '2.5',
#    '2018': '3.6',
#    '2019': '2.4',
#    '2020': '8.3',
#    '2021': '7.7',
#    '2022': '0.8',
#    '2023': '5.3'},
#   'PerCapitaIncomeChangePercentile': {'Value': 51.688311688311686},
#   'PerCapitaIncomeChange5Years': {'Value': '4.9'},
#   'PerCapitaIncomeChange5YearsPercentile': {'Value': 22.597402597402596},
#   'PerCapitaIncomeChange10Years': {'Value': '3.7'},
#   'PerCapitaIncomeChange10YearsPercentile': {'Value': 14.285714285714285},
#   'PerCapitaIncomeChange20Years': {'Value': '3.2'},
#   'PerCapitaIncomeChange20YearsPercentile': {'Value': 7.012987012987012},
#   'PerCapitaIncomeChange30Years': {'Value': '3.4'},
#   'PerCapitaIncomeChange30YearsPercentile': {'Value': 8.571428571428571}},
#  {'GeoFips': '49700',
#   'GeoName': 'Yuba City, CA (Metropolitan Statistical Area)',
#   'Population': {'1969': '86435',
#    '1970': '87104',
#    '1971': '88345',
#    '1972': '87505',
#    '1973': '89980',
#    '1974': '91363',
#    '1975': '92830',
#    '1976': '95979',
#    '1977': '96962',
#    '1978': '98325',
#    '1979': '100611',
#    '1980': '102388',
#    '1981': '103831',
#    '1982': '106405',
#    '1983': '108483',
#    '1984': '109052',
#    '1985': '110929',
#    '1986': '112256',
#    '1987': '114554',
#    '1988': '116916',
#    '1989': '119714',
#    '1990': '123499',
#    '1991': '126677',
#    '1992': '129886',
#    '1993': '131950',
#    '1994': '134518',
#    '1995': '135323',
#    '1996': '136160',
#    '1997': '136425',
#    '1998': '137016',
#    '1999': '138097',
#    '2000': '139564',
#    '2001': '141387',
#    '2002': '144262',
#    '2003': '147404',
#    '2004': '150226',
#    '2005': '155049',
#    '2006': '160384',
#    '2007': '163720',
#    '2008': '165628',
#    '2009': '165973',
#    '2010': '167196',
#    '2011': '167497',
#    '2012': '167918',
#    '2013': '168982',
#    '2014': '170146',
#    '2015': '171626',
#    '2016': '173529',
#    '2017': '176069',
#    '2018': '177586',
#    '2019': '179785',
#    '2020': '181437',
#    '2021': '182379',
#    '2022': '182922',
#    '2023': '183670'},
#   'PopulationChange5Years': {'Value': '0.7'},
#   'PopulationChange5YearsPercentile': {'Value': 66.23376623376623},
#   'PopulationChange10Years': {'Value': '0.8'},
#   'PopulationChange10YearsPercentile': {'Value': 65.45454545454545},
#   'GeneralPriceIndex': {'Value': '102.722'},
#   'GeneralPriceIndexPercentile': {'Value': 83.8961038961039},
#   'HousingPriceIndex': {'Value': '82.549'},
#   'HousingPriceIndexPercentile': {'Value': 56.36363636363636},
#   'PerCapitaIncome': {'1969': '4065',
#    '1970': '4385',
#    '1971': '4714',
#    '1972': '5184',
#    '1973': '5686',
#    '1974': '6455',
#    '1975': '6889',
#    '1976': '6744',
#    '1977': '7524',
#    '1978': '8139',
#    '1979': '8887',
#    '1980': '9890',
#    '1981': '10603',
#    '1982': '10513',
#    '1983': '10614',
#    '1984': '11977',
#    '1985': '12726',
#    '1986': '13112',
#    '1987': '13780',
#    '1988': '14398',
#    '1989': '15393',
#    '1990': '15689',
#    '1991': '16684',
#    '1992': '17393',
#    '1993': '17644',
#    '1994': '18053',
#    '1995': '18639',
#    '1996': '19229',
#    '1997': '19981',
#    '1998': '21036',
#    '1999': '22713',
#    '2000': '23417',
#    '2001': '23808',
#    '2002': '24556',
#    '2003': '25845',
#    '2004': '27258',
#    '2005': '27982',
#    '2006': '29520',
#    '2007': '31324',
#    '2008': '32595',
#    '2009': '32843',
#    '2010': '33109',
#    '2011': '34010',
#    '2012': '33931',
#    '2013': '35158',
#    '2014': '35648',
#    '2015': '38020',
#    '2016': '38938',
#    '2017': '39212',
#    '2018': '40978',
#    '2019': '42721',
#    '2020': '47642',
#    '2021': '51568',
#    '2022': '50207',
#    '2023': '52354'},
#   'PerCapitaIncomePercentile': {'Value': 23.116883116883116},
#   'PerCapitaIncomeChange': {'1970': '7.9',
#    '1971': '7.5',
#    '1972': '10',
#    '1973': '9.7',
#    '1974': '13.5',
#    '1975': '6.7',
#    '1976': '-2.1',
#    '1977': '11.6',
#    '1978': '8.2',
#    '1979': '9.2',
#    '1980': '11.3',
#    '1981': '7.2',
#    '1982': '-0.8',
#    '1983': '1',
#    '1984': '12.8',
#    '1985': '6.3',
#    '1986': '3',
#    '1987': '5.1',
#    '1988': '4.5',
#    '1989': '6.9',
#    '1990': '1.9',
#    '1991': '6.3',
#    '1992': '4.2',
#    '1993': '1.4',
#    '1994': '2.3',
#    '1995': '3.2',
#    '1996': '3.2',
#    '1997': '3.9',
#    '1998': '5.3',
#    '1999': '8',
#    '2000': '3.1',
#    '2001': '1.7',
#    '2002': '3.1',
#    '2003': '5.2',
#    '2004': '5.5',
#    '2005': '2.7',
#    '2006': '5.5',
#    '2007': '6.1',
#    '2008': '4.1',
#    '2009': '0.8',
#    '2010': '0.8',
#    '2011': '2.7',
#    '2012': '-0.2',
#    '2013': '3.6',
#    '2014': '1.4',
#    '2015': '6.7',
#    '2016': '2.4',
#    '2017': '0.7',
#    '2018': '4.5',
#    '2019': '4.3',
#    '2020': '11.5',
#    '2021': '8.2',
#    '2022': '-2.6',
#    '2023': '4.3'},
#   'PerCapitaIncomeChangePercentile': {'Value': 22.597402597402596},
#   'PerCapitaIncomeChange5Years': {'Value': '5'},
#   'PerCapitaIncomeChange5YearsPercentile': {'Value': 27.53246753246753},
#   'PerCapitaIncomeChange10Years': {'Value': '4.1'},
#   'PerCapitaIncomeChange10YearsPercentile': {'Value': 36.88311688311688},
#   'PerCapitaIncomeChange20Years': {'Value': '3.6'},
#   'PerCapitaIncomeChange20YearsPercentile': {'Value': 38.18181818181818},
#   'PerCapitaIncomeChange30Years': {'Value': '3.7'},
#   'PerCapitaIncomeChange30YearsPercentile': {'Value': 33.506493506493506}},
#  {'GeoFips': '49740',
#   'GeoName': 'Yuma, AZ (Metropolitan Statistical Area) *',
#   'Population': {'1969': '59800',
#    '1970': '61415',
#    '1971': '64853',
#    '1972': '67150',
#    '1973': '68685',
#    '1974': '71396',
#    '1975': '69434',
#    '1976': '76476',
#    '1977': '79454',
#    '1978': '80680',
#    '1979': '83512',
#    '1980': '91393',
#    '1981': '91834',
#    '1982': '93878',
#    '1983': '84027',
#    '1984': '85373',
#    '1985': '87572',
#    '1986': '90505',
#    '1987': '92684',
#    '1988': '97064',
#    '1989': '103380',
#    '1990': '108063',
#    '1991': '111967',
#    '1992': '118660',
#    '1993': '124892',
#    '1994': '127975',
#    '1995': '131776',
#    '1996': '137248',
#    '1997': '143896',
#    '1998': '149065',
#    '1999': '155665',
#    '2000': '160576',
#    '2001': '162873',
#    '2002': '165398',
#    '2003': '168003',
#    '2004': '172824',
#    '2005': '178816',
#    '2006': '183848',
#    '2007': '187357',
#    '2008': '191202',
#    '2009': '193714',
#    '2010': '196839',
#    '2011': '201291',
#    '2012': '199666',
#    '2013': '198339',
#    '2014': '198670',
#    '2015': '198510',
#    '2016': '199165',
#    '2017': '199915',
#    '2018': '200572',
#    '2019': '202099',
#    '2020': '205659',
#    '2021': '207284',
#    '2022': '208874',
#    '2023': '213221'},
#   'PopulationChange5Years': {'Value': '1.2'},
#   'PopulationChange5YearsPercentile': {'Value': 81.03896103896103},
#   'PopulationChange10Years': {'Value': '0.7'},
#   'PopulationChange10YearsPercentile': {'Value': 62.59740259740259},
#   'GeneralPriceIndex': {'Value': '86.103'},
#   'GeneralPriceIndexPercentile': {'Value': 3.3766233766233764},
#   'HousingPriceIndex': {'Value': '59.091'},
#   'HousingPriceIndexPercentile': {'Value': 15.584415584415583},
#   'PerCapitaIncome': {'1969': '3503',
#    '1970': '3828',
#    '1971': '4195',
#    '1972': '4421',
#    '1973': '4713',
#    '1974': '5806',
#    '1975': '6223',
#    '1976': '6348',
#    '1977': '6553',
#    '1978': '7198',
#    '1979': '8418',
#    '1980': '8668',
#    '1981': '9404',
#    '1982': '9628',
#    '1983': '10302',
#    '1984': '11456',
#    '1985': '12380',
#    '1986': '12642',
#    '1987': '13931',
#    '1988': '14795',
#    '1989': '14241',
#    '1990': '14187',
#    '1991': '15089',
#    '1992': '15312',
#    '1993': '15839',
#    '1994': '15721',
#    '1995': '17851',
#    '1996': '16536',
#    '1997': '16974',
#    '1998': '18018',
#    '1999': '17458',
#    '2000': '17937',
#    '2001': '18747',
#    '2002': '20228',
#    '2003': '21615',
#    '2004': '23540',
#    '2005': '24215',
#    '2006': '24859',
#    '2007': '26307',
#    '2008': '26715',
#    '2009': '26792',
#    '2010': '27791',
#    '2011': '28558',
#    '2012': '28301',
#    '2013': '30017',
#    '2014': '29745',
#    '2015': '31949',
#    '2016': '33033',
#    '2017': '34809',
#    '2018': '35266',
#    '2019': '36928',
#    '2020': '41995',
#    '2021': '44461',
#    '2022': '45028',
#    '2023': '46441'},
#   'PerCapitaIncomePercentile': {'Value': 3.636363636363636},
#   'PerCapitaIncomeChange': {'1970': '9.3',
#    '1971': '9.6',
#    '1972': '5.4',
#    '1973': '6.6',
#    '1974': '23.2',
#    '1975': '7.2',
#    '1976': '2',
#    '1977': '3.2',
#    '1978': '9.8',
#    '1979': '16.9',
#    '1980': '3',
#    '1981': '8.5',
#    '1982': '2.4',
#    '1983': '7',
#    '1984': '11.2',
#    '1985': '8.1',
#    '1986': '2.1',
#    '1987': '10.2',
#    '1988': '6.2',
#    '1989': '-3.7',
#    '1990': '-0.4',
#    '1991': '6.4',
#    '1992': '1.5',
#    '1993': '3.4',
#    '1994': '-0.7',
#    '1995': '13.5',
#    '1996': '-7.4',
#    '1997': '2.6',
#    '1998': '6.2',
#    '1999': '-3.1',
#    '2000': '2.7',
#    '2001': '4.5',
#    '2002': '7.9',
#    '2003': '6.9',
#    '2004': '8.9',
#    '2005': '2.9',
#    '2006': '2.7',
#    '2007': '5.8',
#    '2008': '1.6',
#    '2009': '0.3',
#    '2010': '3.7',
#    '2011': '2.8',
#    '2012': '-0.9',
#    '2013': '6.1',
#    '2014': '-0.9',
#    '2015': '7.4',
#    '2016': '3.4',
#    '2017': '5.4',
#    '2018': '1.3',
#    '2019': '4.7',
#    '2020': '13.7',
#    '2021': '5.9',
#    '2022': '1.3',
#    '2023': '3.1'},
#   'PerCapitaIncomeChangePercentile': {'Value': 4.9350649350649345},
#   'PerCapitaIncomeChange5Years': {'Value': '5.7'},
#   'PerCapitaIncomeChange5YearsPercentile': {'Value': 63.11688311688311},
#   'PerCapitaIncomeChange10Years': {'Value': '4.5'},
#   'PerCapitaIncomeChange10YearsPercentile': {'Value': 60.77922077922077},
#   'PerCapitaIncomeChange20Years': {'Value': '3.9'},
#   'PerCapitaIncomeChange20YearsPercentile': {'Value': 70.38961038961038},
#   'PerCapitaIncomeChange30Years': {'Value': '3.7'},
#   'PerCapitaIncomeChange30YearsPercentile': {'Value': 33.506493506493506}}]
